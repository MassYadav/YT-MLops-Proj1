# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import RandomOverSampler
sns.set(style='whitegrid')

import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://mky80094:lsldWRAMLchcqlJU@cluster0.dty8p5m.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Uploading data to MongoDB
# ----> 2 rec = collection.insert_many(data)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)    600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2076, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2062 """Execute an operation with consecutive retries if possible
#    2063
#    2064 Returns func()'s return value on success. On error retries the same
#    (...)   2073 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2074 """
#    2075 with self._tmp_session(session) as s:
# -> 2076     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1962, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1957 # Ensure that the options supports retry_writes and there is a valid session not in
#    1958 # transaction, otherwise, we will not support retry behavior for this txn.
#    1959 retryable = bool(
#    1960     retryable and self.options.retry_writes and session and not session.in_transaction
#    1961 )
# -> 1962 return self._retry_internal(
#    1963     func=func,
#    1964     session=session,
#    1965     bulk=bulk,
#    1966     operation=operation,
#    1967     retryable=retryable,
#    1968     operation_id=operation_id,
#    1969 )
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2008, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1971 @_csot.apply
#    1972 def _retry_internal(
#    1973     self,
#    (...)   1982     operation_id: Optional[int] = None,
#    1983 ) -> T:
#    1984     """Internal retryable helper for all client transactions.
#    1985
#    1986     :param func: Callback function we want to retry
#    (...)   1995     :return: Output of the calling func()
#    1996     """
#    1997     return _ClientConnectionRetryable(
#    1998         mongo_client=self,
#    1999         func=func,
#    2000         bulk=bulk,
#    2001         operation=operation,
#    2002         is_read=is_read,
#    2003         session=session,
#    2004         read_pref=read_pref,
#    2005         address=address,
#    2006         retryable=retryable,
#    2007         operation_id=operation_id,
# -> 2008     ).run()
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2745, in _ClientConnectionRetryable.run(self)
#    2743 self._check_last_error(check_csot=True)
#    2744 try:
# -> 2745     return self._read() if self._is_read else self._write()
#    2746 except ServerSelectionTimeoutError:
#    2747     # The application may think the write was never attempted
#    2748     # if we raise ServerSelectionTimeoutError on the retry
#    2749     # attempt. Raise the original exception instead.
#    2750     self._check_last_error()
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2856, in _ClientConnectionRetryable._write(self)
#    2854 is_mongos = False
#    2855 self._server = self._get_server()
# -> 2856 with self._client._checkout(self._server, self._session) as conn:
#    2857     max_wire_version = conn.max_wire_version
#    2858     sessions_supported = (
#    2859         self._session
#    2860         and self._server.description.retryable_writes_supported
#    2861         and conn.supports_sessions
#    2862     )
#
# File C:\Program Files\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1771, in MongoClient._checkout(self, server, session)
#    1769     yield session._pinned_connection
#    1770     return
# -> 1771 with server.checkout(handler=err_handler) as conn:
#    1772     # Pin this session to the selected server or connection.
#    1773     if (
#    1774         in_txn
#    1775         and session
#    (...)   1780         )
#    1781     ):
#    1782         session._pin(server, conn)
#
# File C:\Program Files\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:1119, in Pool.checkout(self, handler)
#    1110 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1111     _debug_log(
#    1112         _CONNECTION_LOGGER,
#    1113         message=_ConnectionStatusMessage.CHECKOUT_STARTED,
#    (...)   1116         serverPort=self.address[1],
#    1117     )
# -> 1119 conn = self._get_conn(checkout_started_time, handler=handler)
#    1121 duration = time.monotonic() - checkout_started_time
#    1122 if self.enabled_for_cmap:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:1281, in Pool._get_conn(self, checkout_started_time, handler)
#    1279 else:  # We need to create a new connection
#    1280     try:
# -> 1281         conn = self.connect(handler=handler)
#    1282     finally:
#    1283         with self._max_connecting_cond:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:1073, in Pool.connect(self, handler)
#    1070     if handler:
#    1071         handler.contribute_socket(conn, completed_handshake=False)
# -> 1073     conn.authenticate()
#    1074 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1075 except BaseException:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:526, in Connection.authenticate(self, reauthenticate)
#     523 if creds:
#     524     from pymongo.synchronous import auth
# --> 526     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     527 self.ready = True
#     528 duration = time.monotonic() - self.creation_time
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\auth.py:450, in authenticate(credentials, conn, reauthenticate)
#     448     _authenticate_oidc(credentials, conn, reauthenticate)
#     449 else:
# --> 450     auth_func(credentials, conn)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\auth.py:355, in _authenticate_default(credentials, conn)
#     353         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354     else:
# --> 355         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356 else:
#     357     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\auth.py:135, in _authenticate_scram(credentials, conn, mechanism)
#     128 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     130 cmd = {
#     131     "saslContinue": 1,
#     132     "conversationId": res["conversationId"],
#     133     "payload": Binary(client_final),
#     134 }
# --> 135 res = conn.command(source, cmd)
#     137 parsed = _parse_scram_response(res["payload"])
#     138 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:414, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     412     self._raise_if_not_writable(unacknowledged)
#     413 try:
# --> 414     return command(
#     415         self,
#     416         dbname,
#     417         spec,
#     418         self.is_mongos,
#     419         read_preference,
#     420         codec_options,
#     421         session,
#     422         client,
#     423         check,
#     424         allowable_errors,
#     425         self.address,
#     426         listeners,
#     427         self.max_bson_size,
#     428         read_concern,
#     429         parse_write_concern_error=parse_write_concern_error,
#     430         collation=collation,
#     431         compression_ctx=self.compression_context,
#     432         use_op_msg=self.op_msg_enabled,
#     433         unacknowledged=unacknowledged,
#     434         user_fields=user_fields,
#     435         exhaust_allowed=exhaust_allowed,
#     436         write_concern=write_concern,
#     437     )
#     438 except (OperationFailure, NotPrimaryError):
#     439     raise
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\helpers_shared.py:250, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     247 elif code == 43:
#     248     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 250 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
# Load back data from mongodb

df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Load back data from mongodb
# ----> 3 df = pd.DataFrame(list(collection.find()))
#       4 df.head(2)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\cursor.py:1285, in Cursor.__next__(self)
#    1284 def __next__(self) -> _DocumentType:
# -> 1285     return self.next()
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\cursor.py:1261, in Cursor.next(self)
#    1259 if self._empty:
#    1260     raise StopIteration
# -> 1261 if len(self._data) or self._refresh():
#    1262     return self._data.popleft()
#    1263 else:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\cursor.py:1209, in Cursor._refresh(self)
#    1187         raise InvalidOperation(
#    1188             "Passing a 'hint' is required when using the min/max query"
#    1189             " option to ensure the query utilizes the correct index"
#    1190         )
#    1191     q = self._query_class(
#    1192         self._query_flags,
#    1193         self._collection.database.name,
#    (...)   1207         self._exhaust,
#    1208     )
# -> 1209     self._send_message(q)
#    1210 elif self._id:  # Get More
#    1211     if self._limit:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\cursor.py:1104, in Cursor._send_message(self, operation)
#    1101     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1103 try:
# -> 1104     response = client._run_operation(
#    1105         operation, self._unpack_response, address=self._address
#    1106     )
#    1107 except OperationFailure as exc:
#    1108     if exc.code in _CURSOR_CLOSED_ERRORS or self._exhaust:
#    1109         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1932, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1922     operation.reset()  # Reset op in case of retry.
#    1923     return server.run_operation(
#    1924         conn,
#    1925         operation,
#    (...)   1929         self,
#    1930     )
# -> 1932 return self._retryable_read(
#    1933     _cmd,
#    1934     operation.read_preference,
#    1935     operation.session,  # type: ignore[arg-type]
#    1936     address=address,
#    1937     retryable=isinstance(operation, _Query),
#    1938     operation=operation.name,
#    1939 )
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2041, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2036 # Ensure that the client supports retrying on reads and there is no session in
#    2037 # transaction, otherwise, we will not support retry behavior for this call.
#    2038 retryable = bool(
#    2039     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2040 )
# -> 2041 return self._retry_internal(
#    2042     func,
#    2043     session,
#    2044     None,
#    2045     operation,
#    2046     is_read=True,
#    2047     address=address,
#    2048     read_pref=read_pref,
#    2049     retryable=retryable,
#    2050     operation_id=operation_id,
#    2051 )
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2008, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1971 @_csot.apply
#    1972 def _retry_internal(
#    1973     self,
#    (...)   1982     operation_id: Optional[int] = None,
#    1983 ) -> T:
#    1984     """Internal retryable helper for all client transactions.
#    1985
#    1986     :param func: Callback function we want to retry
#    (...)   1995     :return: Output of the calling func()
#    1996     """
#    1997     return _ClientConnectionRetryable(
#    1998         mongo_client=self,
#    1999         func=func,
#    2000         bulk=bulk,
#    2001         operation=operation,
#    2002         is_read=is_read,
#    2003         session=session,
#    2004         read_pref=read_pref,
#    2005         address=address,
#    2006         retryable=retryable,
#    2007         operation_id=operation_id,
# -> 2008     ).run()
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2745, in _ClientConnectionRetryable.run(self)
#    2743 self._check_last_error(check_csot=True)
#    2744 try:
# -> 2745     return self._read() if self._is_read else self._write()
#    2746 except ServerSelectionTimeoutError:
#    2747     # The application may think the write was never attempted
#    2748     # if we raise ServerSelectionTimeoutError on the retry
#    2749     # attempt. Raise the original exception instead.
#    2750     self._check_last_error()
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:2892, in _ClientConnectionRetryable._read(self)
#    2890 self._server = self._get_server()
#    2891 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2892 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2893     conn,
#    2894     read_pref,
#    2895 ):
#    2896     if self._retrying and not self._retryable:
#    2897         self._check_last_error()
#
# File C:\Program Files\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1861, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1852 # Get a connection for a server matching the read preference, and yield
#    1853 # conn with the effective read preference. The Server Selection
#    1854 # Spec says not to send any $readPreference to standalones and to
#    (...)   1858 # NOTE: We already opened the Topology when selecting a server so there's no need
#    1859 # to call _get_topology() again.
#    1860 single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1861 with self._checkout(server, session) as conn:
#    1862     if single:
#    1863         if conn.is_repl and not (session and session.in_transaction):
#    1864             # Use primary preferred to ensure any repl set member
#    1865             # can handle the request.
#
# File C:\Program Files\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:1771, in MongoClient._checkout(self, server, session)
#    1769     yield session._pinned_connection
#    1770     return
# -> 1771 with server.checkout(handler=err_handler) as conn:
#    1772     # Pin this session to the selected server or connection.
#    1773     if (
#    1774         in_txn
#    1775         and session
#    (...)   1780         )
#    1781     ):
#    1782         session._pin(server, conn)
#
# File C:\Program Files\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:1119, in Pool.checkout(self, handler)
#    1110 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1111     _debug_log(
#    1112         _CONNECTION_LOGGER,
#    1113         message=_ConnectionStatusMessage.CHECKOUT_STARTED,
#    (...)   1116         serverPort=self.address[1],
#    1117     )
# -> 1119 conn = self._get_conn(checkout_started_time, handler=handler)
#    1121 duration = time.monotonic() - checkout_started_time
#    1122 if self.enabled_for_cmap:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:1281, in Pool._get_conn(self, checkout_started_time, handler)
#    1279 else:  # We need to create a new connection
#    1280     try:
# -> 1281         conn = self.connect(handler=handler)
#    1282     finally:
#    1283         with self._max_connecting_cond:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:1073, in Pool.connect(self, handler)
#    1070     if handler:
#    1071         handler.contribute_socket(conn, completed_handshake=False)
# -> 1073     conn.authenticate()
#    1074 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1075 except BaseException:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:526, in Connection.authenticate(self, reauthenticate)
#     523 if creds:
#     524     from pymongo.synchronous import auth
# --> 526     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     527 self.ready = True
#     528 duration = time.monotonic() - self.creation_time
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\auth.py:450, in authenticate(credentials, conn, reauthenticate)
#     448     _authenticate_oidc(credentials, conn, reauthenticate)
#     449 else:
# --> 450     auth_func(credentials, conn)
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\auth.py:355, in _authenticate_default(credentials, conn)
#     353         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354     else:
# --> 355         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356 else:
#     357     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\auth.py:135, in _authenticate_scram(credentials, conn, mechanism)
#     128 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     130 cmd = {
#     131     "saslContinue": 1,
#     132     "conversationId": res["conversationId"],
#     133     "payload": Binary(client_final),
#     134 }
# --> 135 res = conn.command(source, cmd)
#     137 parsed = _parse_scram_response(res["payload"])
#     138 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\pool.py:414, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     412     self._raise_if_not_writable(unacknowledged)
#     413 try:
# --> 414     return command(
#     415         self,
#     416         dbname,
#     417         spec,
#     418         self.is_mongos,
#     419         read_preference,
#     420         codec_options,
#     421         session,
#     422         client,
#     423         check,
#     424         allowable_errors,
#     425         self.address,
#     426         listeners,
#     427         self.max_bson_size,
#     428         read_concern,
#     429         parse_write_concern_error=parse_write_concern_error,
#     430         collation=collation,
#     431         compression_ctx=self.compression_context,
#     432         use_op_msg=self.op_msg_enabled,
#     433         unacknowledged=unacknowledged,
#     434         user_fields=user_fields,
#     435         exhaust_allowed=exhaust_allowed,
#     436         write_concern=write_concern,
#     437     )
#     438 except (OperationFailure, NotPrimaryError):
#     439     raise
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\synchronous\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\Users\mass0\OneDrive\Desktop\yt-mlops-se\YT-MLops-Proj1\.venv\Lib\site-packages\pymongo\helpers_shared.py:250, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     247 elif code == 43:
#     248     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 250 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}
